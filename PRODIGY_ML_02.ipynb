# %% [markdown]
# # Create a K-means clustering algorithm to group customers of a retail store based on their purchase history.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("Mall_Customers.csv")
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.shape
# Out:
# (200, 5)

# %%
data.info
# Out:
# <bound method DataFrame.info of      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
df1=data.iloc[:,2:5]
df1
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
distortation=[]
k=range(1,20)
k
# Out:
# range(1, 20)

# %%
from sklearn.cluster import KMeans

# %%
for i in k:
    KMeanmodel=KMeans(n_clusters=i,max_iter=25)
    KMeanmodel.fit(df1)
    distortation.append(KMeanmodel.inertia_)
# Out:
# D:\NPTEL CERTIFICATIONS\PYTHON FOR DATA SCIENCE\ANACONDA\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\NPTEL CERTIFICATIONS\PYTHON FOR DATA SCIENCE\ANACONDA\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# D:\NPTEL CERTIFICATIONS\PYTHON FOR DATA SCIENCE\ANACONDA\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(figure=(16,8))
plt.plot(k,distortation,'bo-')
plt.xlabel('no of cluster')
plt.ylabel("WSS")
plt.title("Elbow method")
# Out:
# Text(0.5, 1.0, 'Elbow method')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     200 non-null    int64
#  1   Annual Income (k$)      200 non-null    int64
#  2   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3)
# memory usage: 4.8 KB

# %%
final_model1=KMeans(n_clusters=6,max_iter=25)
final_model1.fit(df1)
final_model1.cluster_centers_
final_model1.feature_names_in_
final_model1.labels_
# Out:
# D:\NPTEL CERTIFICATIONS\PYTHON FOR DATA SCIENCE\ANACONDA\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\NPTEL CERTIFICATIONS\PYTHON FOR DATA SCIENCE\ANACONDA\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3,
#        4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 4, 3, 2, 3, 2, 5,
#        4, 3, 2, 5, 5, 5, 2, 5, 5, 2, 2, 2, 2, 2, 5, 2, 2, 5, 2, 2, 2, 5,
#        2, 2, 5, 5, 2, 2, 2, 2, 2, 5, 2, 5, 5, 2, 2, 5, 2, 2, 5, 2, 2, 5,
#        5, 2, 2, 5, 2, 5, 5, 5, 2, 5, 2, 5, 5, 2, 2, 5, 2, 5, 2, 2, 2, 2,
# ...

# %%
plt.scatter(df1['Spending Score (1-100)'],df1['Annual Income (k$)'],c=final_model1.labels_)

# %%
final_model2=KMeans(n_clusters=7,max_iter=25)
final_model2.fit(df1)
final_model2.cluster_centers_
final_model2.feature_names_in_
final_model2.labels_
# Out:
# D:\NPTEL CERTIFICATIONS\PYTHON FOR DATA SCIENCE\ANACONDA\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\NPTEL CERTIFICATIONS\PYTHON FOR DATA SCIENCE\ANACONDA\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4,
#        5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 5, 4, 2, 4, 2, 1,
#        5, 4, 2, 1, 1, 1, 2, 1, 1, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1,
#        2, 2, 1, 1, 2, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1,
#        1, 2, 2, 1, 2, 1, 1, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2, 1, 2, 2, 2, 2,
# ...

# %%
plt.scatter(df1['Spending Score (1-100)'],df1['Annual Income (k$)'],c=final_model2.labels_)
